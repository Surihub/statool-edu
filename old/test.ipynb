# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statool import 시각화, 그리기, 데이터처리

# 예시 데이터 
데이터 = sns.load_dataset('penguins')
데이터처리.미리보기(데이터)
# Out:
# 344행, 7열로 이루어진 자료입니다.
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...

# %%
시각화.히스토그램(데이터, 'body_mass_g', 2000, 200)

# %%
시각화.상자그림(데이터, 'body_mass_g')

# %%
시각화.막대그래프(데이터, 'species')

# %%
시각화.원그래프(데이터, 'island')

# %%
from statool import 통계분석
import seaborn as sns

팁데이터 = sns.load_dataset('tips')
# 통계분석.추정(팁데이터, "tip", 0.98, True) # 모표준편차 알 때 
# 통계분석.추정(팁데이터, "tip", 0.98, False) # 모표준편차 모를 때

# 통계분석.검정(팁데이터, "tip", 0.05, 기준값, True) # 모표준편차 알 때
# 통계분석.검정(팁데이터, "tip", 0.05, 기준값, False) # 모표준편차 모를 때

# %%
from statool import 통계분석
import seaborn as sns
import numpy as np

팁데이터 = sns.load_dataset('tips')

통계분석.모평균추정(팁데이터, 'tip', 0.95, 1)
통계분석.모평균검정(팁데이터, 'tip', 0.05, 3, 'less' , 1)

통계분석.모비율추정(팁데이터, 'sex', 'Male', 0.95)
통계분석.모비율검정(팁데이터, 'sex', 'Male', 0.05, 0.5, 'less')
# Out:
# ********************************************
# tip에 대한 95.0% 신뢰구간:: (2.8728, 3.1238), 표본평균: 2.9983
# ********************************************
# 귀무가설: tip의 평균은 3 이상입니다.
# 대립가설: tip의 평균은 3 미만입니다.
# p값이 0.9785로, 유의수준 0.05 보다 크다. 따라서 귀무가설을 기각할 수 없다.
# ********************************************
# sex에 대한 95.0% 신뢰구간: (0.5833, 0.7035), 표본비율: 0.6434
# ********************************************
# 귀무가설: sex의 비율은 0.5000 이하입니다.
# 대립가설: sex의 비율은 0.5000 초과입니다.
# p값이 1.0000로, 유의수준 0.05 보다 크다. 따라서 귀무가설을 기각할 수 없다.

# %%
통계분석.모평균검정(팁데이터, 'tip', 0.05, 3, 'two-sided' , 1)
통계분석.모평균검정(팁데이터, 'tip', 0.05, 3, 'two-sided')
통계분석.모평균검정(팁데이터, 'tip', 0.05, 3, 'less')
통계분석.모평균검정(팁데이터, 'tip', 0.05, 3, 'greater')
# Out:
# ********************************************
# tip에 대한 95.0% 신뢰구간:: (2.8728, 3.1238), 표본평균: 2.9983
# ********************************************
# tip에 대한 95.0% 신뢰구간:: (2.8238, 3.1728), 표본평균: 2.9983
# ********************************************
# 귀무가설: tip의 평균은 3입니다.
# 대립가설: tip의 평균은 3가 아닙니다.
# p값이 0.9785로, 유의수준 0.05 보다 크다. 따라서 귀무가설을 기각할 수 없다.
# ********************************************
# 귀무가설: tip의 평균은 3입니다.
# 대립가설: tip의 평균은 3가 아닙니다.
# p값이 0.9845로, 유의수준 0.05 보다 크다. 따라서 귀무가설을 기각할 수 없다.
# ********************************************
# 귀무가설: tip의 평균은 3 이상입니다.
# 대립가설: tip의 평균은 3 미만입니다.
# p값이 0.4923로, 유의수준 0.05 보다 크다. 따라서 귀무가설을 기각할 수 없다.
# ********************************************
# 귀무가설: tip의 평균은 3 이하입니다.
# 대립가설: tip의 평균은 3 초과입니다.
# p값이 0.5077로, 유의수준 0.05 보다 크다. 따라서 귀무가설을 기각할 수 없다.

# %%
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
