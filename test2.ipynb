# %%
from sklearn import datasets
from statool import 인공지능, 데이터처리
import pandas as pd

# 데이터 불러오기
wine_df = 인공지능.데이터불러오기('와인')
데이터처리.미리보기(wine_df,6)
데이터처리.기초통계(wine_df)
# Out:
# 178행, 14열로 이루어진 자료입니다.
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# ...

# %%
X_test
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 19     13.64        3.10  2.56               15.2      116.0           2.70
# 45     14.21        4.04  2.44               18.9      111.0           2.85
# 140    12.93        2.81  2.70               21.0       96.0           1.54
# 30     13.73        1.50  2.70               22.5      101.0           3.00
# 67     12.37        1.17  1.92               19.6       78.0           2.11
# 16     14.30        1.92  2.72               20.0      120.0           2.80
# 119    12.00        3.43  2.00               19.0       87.0           2.00
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 109    11.61        1.35  2.70               20.0       94.0           2.74
# 141    13.36        2.56  2.35               20.0       89.0           1.40
# 24     13.50        1.81  2.61               20.0       96.0           2.53
# ...

# %%
# 데이터 분할
X_train, X_test, y_train, y_test = 인공지능.데이터분할하기(wine_df)

# 모델 훈련
선형_모델 = 인공지능.모델_훈련(X_train, y_train, '선형')
이차식_모델 = 인공지능.모델_훈련(X_train, y_train, '이차식')

# %%
y_pred = 인공지능.모델_평가(X_test, y_test, 선형_모델)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\project_sbh\statool-edu\statool-edu\test2.ipynb 셀 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/project_sbh/statool-edu/statool-edu/test2.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> 인공지능.모델_평가(X_test, y_test, 선형_모델)
#
# File c:\project_sbh\statool-edu\statool-edu\statool\인공지능.py:69, in 모델_평가(X_test, y_test, model)
#      66 y_pred = model.predict(X_test)
#      68 # 정확도 계산
# ---> 69 cm = confusion_matrix(y_test, y_pred)
#      71 # 실제_라벨 = [f'실제{i}' for i in range(len(cm))]
#      72 # 예측_라벨 = [f'예측{i}' for i in range(len(cm))]
#      73 # confusion_df = pd.DataFrame(cm, columns=실제_라벨, index=예측_라벨)
#      74
#      75
#      76 # code
#      79 return cm
#
# File c:\Anaconda\envs\pytorch_sbh\lib\site-packages\sklearn\metrics\_classification.py:317, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

y_test = [1, 0, 1, 2, 0, 1]
y_pred = [0, 0, 1, 1, 0, 1]

confusion_matrix(y_test, y_pred)
# Out:
# array([[2, 0, 0],
#        [1, 2, 0],
#        [0, 1, 0]], dtype=int64)

# %%
# 모델 평가
선형_정확도 = 인공지능.모델_평가(X_test, y_test, 선형_모델)
이차식_정확도 = 인공지능.모델_평가(X_test, y_test, 이차식_모델)

print(f'선형 모델 정확도: {선형_정확도 * 100:.2f}%')
print(f'이차식 모델 정확도: {이차식_정확도 * 100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\project_sbh\statool-edu\statool-edu\test2.ipynb 셀 2 line 9
#       <a href='vscode-notebook-cell:/c%3A/project_sbh/statool-edu/statool-edu/test2.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> 이차식_모델 = 인공지능.모델_훈련(X_train, y_train, '이차식')
#       <a href='vscode-notebook-cell:/c%3A/project_sbh/statool-edu/statool-edu/test2.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> # 모델 평가
# ----> <a href='vscode-notebook-cell:/c%3A/project_sbh/statool-edu/statool-edu/test2.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> 선형_정확도 = 인공지능.모델_평가(X_test, y_test, 선형_모델)
#      <a href='vscode-notebook-cell:/c%3A/project_sbh/statool-edu/statool-edu/test2.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> 이차식_정확도 = 인공지능.모델_평가(X_test, y_test, 이차식_모델)
# ...

# %%
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...
